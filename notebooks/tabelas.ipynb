# %% [markdown]
# Separação das tabelas em dados pessoais e dados bancários para otimização e segurança dos dados

# %%
import pandas as pan

dfs = pan.read_csv('silver_dfo.csv', sep=',')

# %%
colunas_pessoais = ["Id_do_Cliente", "Nome", "Idade", "SSN", "Profissao"]
df_pessoais = dfs[colunas_pessoais].copy()

df_pessoais = df_pessoais.drop_duplicates(subset=["Id_do_Cliente"], keep="last")

colunas_bancarias = ["Id_do_Cliente", "ID", "Mes", "Taxa_de_Juros", "Numero_de_Emprestimos", "Tipo_de_Emprestimo", "Atraso_na_Data_de_Vencimento", "Numero_de_Pagamentos_Atrasados", "Quantidade_de_Mudancas_de_Limite", "Numero_de_Consultas_de_Credito", "Tipos_de_Creditos", "Saldo_Devedor", "Taxa_de_Utilizacao_de_Credito", "Tempo_de_Uso_de_Credito_em_Meses", "Pagamento_do_Valor_Minimo", "Valor_Total_em_Parcelas_Mensais", "Valor_Total_Investido_Mensalmente", "Comportamento_de_Pagamento", "Pontuacao_de_Credito", "Numero_de_Contas_Bancarias", "Numero_de_Cartoes_de_Credito", "Renda_Anual", "Salario_Liquido_Mensal", "Saldo_Mensal"]

df_bancarios = dfs[colunas_bancarias].copy()

# %%
print(df_pessoais),
print(df_bancarios)
# Out:
#        Id_do_Cliente            Nome  Idade        SSN      Profissao
# 11        CUS_0x1000  Alistair Barrf     18  913741218         Lawyer
# 23        CUS_0x1009          Arunah     26   63676938       Mechanic
# 35        CUS_0x100b        Shirboni     19  238620395  Media Manager
# 47        CUS_0x1011       Schneyerh     44  793058223         Doctor
# 59        CUS_0x1013        Cameront     44  930499615       Mechanic
# ...              ...             ...    ...        ...            ...
# 149951     CUS_0xff3     Somervilled     56  726355322      Scientist
# 149963     CUS_0xff4       Poornimaf     37  655057666   Entrepreneur
# 149975     CUS_0xff6        Shieldsb     19  541928371         Doctor
# 149987     CUS_0xffc           Brads     18  226867294       Musician
# 149999     CUS_0xffd        Damouniq     30  832888320      Scientist
#
# [12500 rows x 5 columns]
#        Id_do_Cliente       ID        Mes  Taxa_de_Juros  \
# ...
